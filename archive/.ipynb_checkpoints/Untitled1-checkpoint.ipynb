# %%
import os, shutil, pathlib
from tensorflow.keras.preprocessing import image_dataset_from_directory
import matplotlib.pyplot as plt
from pathlib import Path
import numpy as np

# %%
train_ds = image_dataset_from_directory(
    base_dir / "train", 
    image_size=(180, 180),
    batch_size=32
)

# %%
p = Path().cwd()
q = p.joinpath('archive', 'train')

images = [] # create an empty list
labels = [] # create an empty list

for fldr in q.iterdir(): 
    current_label = fldr.name
    for img in fldr.iterdir():
        img = load_img(img)
        img_array =  img_to_array(img) # convert the image to an NumPy array 
        img_array_resized =  smart_resize(img_array, (128, 128)) # if necessary, resize the image to 128 by 128 
        img_array_reshaped = img_array_resized.reshape(128, 128) # reshape the image from (height, width, 1) to (height, width)
        images.append(img_array_reshaped) # add reshaped image to list of images 
        labels.append(target_dict[current_label]) # add label for this image to the list of labels 

images = np.array(images) # convert the list of images to a NumPy array 
labels = np.array(labels) # convert the list of labels to a NumPy array
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 7
#       4 images = [] # create an empty list
#       5 labels = [] # create an empty list
# ----> 7 for fldr in q.iterdir():
#       8     current_label = fldr.name
#       9     for img in fldr.iterdir():
#
# File ~\anaconda3\envs\DAB300\lib\pathlib.py:1160, in Path.iterdir(self)
#    1156 def iterdir(self):
#    1157     """Iterate over the files in this directory.  Does not yield any
#    1158     result for the special paths '.' and '..'.
#    1159     """
# -> 1160     for name in self._accessor.listdir(self):
#    1161         if name in {'.', '..'}:
#    1162             # Yielding a path object for these makes little sense
#    1163             continue
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'C:\\Users\\15199\\Capstone\\Capstone-Project---Group-3\\archive\\archive\\train'

# %%
import tensorflow as tf
train_ds = tf.keras.utils.image_dataset_from_directory(q, image_size=(180, 180), batch_size=32)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 2
#       1 import tensorflow as tf
# ----> 2 train_ds = tf.keras.utils.image_dataset_from_directory(q, image_size=(180, 180), batch_size=32)
#
# File ~\anaconda3\envs\DAB300\lib\site-packages\keras\preprocessing\image_dataset.py:192, in image_dataset_from_directory(directory, labels, label_mode, class_names, color_mode, batch_size, image_size, shuffle, seed, validation_split, subset, interpolation, follow_links, crop_to_aspect_ratio, **kwargs)
#     190 if seed is None:
#     191   seed = np.random.randint(1e6)
# --> 192 image_paths, labels, class_names = dataset_utils.index_directory(
#     193     directory,
#     194     labels,
#     195     formats=ALLOWLIST_FORMATS,
#     196     class_names=class_names,
#     197     shuffle=shuffle,
#     198     seed=seed,
#     199     follow_links=follow_links)
#     201 if label_mode == 'binary' and len(class_names) != 2:
#     202   raise ValueError(
#     203       f'When passing `label_mode="binary"`, there must be exactly 2 '
#     204       f'class_names. Received: class_names={class_names}')
#
# File ~\anaconda3\envs\DAB300\lib\site-packages\keras\preprocessing\dataset_utils.py:66, in index_directory(directory, labels, formats, class_names, shuffle, seed, follow_links)
#      64 else:
#      65   subdirs = []
# ---> 66   for subdir in sorted(os.listdir(directory)):
#      67     if os.path.isdir(os.path.join(directory, subdir)):
#      68       subdirs.append(subdir)
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'C:\\Users\\15199\\Capstone\\Capstone-Project---Group-3\\archive\\archive\\train'

# %%
PATH = 'C:\\Users\\15199\\Capstone\\Capstone-Project---Group-3\\archive\\archive'
train_dir = os.path.join(PATH, 'train')


BATCH_SIZE = 1                                              # 32
IMG_SIZE = (32, 32)

train_dataset = tf.keras.utils.image_dataset_from_directory(train_dir,
                                                            shuffle=True,
                                                            batch_size=BATCH_SIZE,
                                                            image_size=IMG_SIZE)
                                                            
                                                            
class_names = train_dataset.class_names

#print('Number of training batches: %d' % tf.data.experimental.cardinality(train_dataset).numpy())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 8
#       5 BATCH_SIZE = 1                                              # 32
#       6 IMG_SIZE = (32, 32)
# ----> 8 train_dataset = tf.keras.utils.image_dataset_from_directory(train_dir,
#       9                                                             shuffle=True,
#      10                                                             batch_size=BATCH_SIZE,
#      11                                                             image_size=IMG_SIZE)
#      14 class_names = train_dataset.class_names
#
# File ~\anaconda3\envs\DAB300\lib\site-packages\keras\preprocessing\image_dataset.py:192, in image_dataset_from_directory(directory, labels, label_mode, class_names, color_mode, batch_size, image_size, shuffle, seed, validation_split, subset, interpolation, follow_links, crop_to_aspect_ratio, **kwargs)
#     190 if seed is None:
#     191   seed = np.random.randint(1e6)
# --> 192 image_paths, labels, class_names = dataset_utils.index_directory(
#     193     directory,
#     194     labels,
#     195     formats=ALLOWLIST_FORMATS,
#     196     class_names=class_names,
#     197     shuffle=shuffle,
#     198     seed=seed,
#     199     follow_links=follow_links)
#     201 if label_mode == 'binary' and len(class_names) != 2:
#     202   raise ValueError(
#     203       f'When passing `label_mode="binary"`, there must be exactly 2 '
#     204       f'class_names. Received: class_names={class_names}')
#
# File ~\anaconda3\envs\DAB300\lib\site-packages\keras\preprocessing\dataset_utils.py:66, in index_directory(directory, labels, formats, class_names, shuffle, seed, follow_links)
#      64 else:
#      65   subdirs = []
# ---> 66   for subdir in sorted(os.listdir(directory)):
#      67     if os.path.isdir(os.path.join(directory, subdir)):
#      68       subdirs.append(subdir)
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'C:\\Users\\15199\\Capstone\\Capstone-Project---Group-3\\archive\\archive\\train'
